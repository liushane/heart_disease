# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('heart.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#相关性分析
plt.figure(figsize=(10,10))
correlation = data.corr()
sns.heatmap(correlation,annot=True,fmt='.2f')

# %%
#age与target的关系
# data_having = data[data.target == 0]
# data_nothaving = data[data.target == 1]
# fig = plt.figure()
# ax1 = fig.add_subplot(1,2,1)
# plt.hist(data_having.age,bins=20)
# ax2 = fig.add_subplot(1,2,2)
# plt.hist(data_nothaving.age,bins=20)

# %%
fig = plt.figure()
facet = sns.FacetGrid(data, hue="target",aspect=2)#hue表示在同一个图中画target类别的图
facet.map(sns.kdeplot,'age',shade= True)#核密度估计(kernel density estimation)
facet.set(xlim=(0, data['age'].max()))
facet.add_legend()
plt.xlabel('age') 
plt.ylabel('density')
# Out:
# Text(10.7163,0.5,'density')

# %%
#sex与target的关系图
sex_data = data.copy()
sex_data.sex = sex_data.sex.replace([0,1],['female','male'])
sns.countplot('sex',hue='target',data=sex_data)

# %%
#疼痛类型cp与target的关系
sns.countplot(x='cp',hue='target',data=data)

# %%
#trestbps与target的关系
sns.boxplot(x='target',y='trestbps',data=data)

# %%
#chol与target的关系
sns.boxplot(x='target',y='chol',data=data)

# %%
#fbs与target的关系 空腹血糖是否大于120
sns.countplot(x='fbs',hue='target',data=data)

# %%
#restecg与target 1or0
sns.countplot(x='restecg',hue='target',data=data)

# %%
#thalach与target   
sns.boxplot(x='target',y='thalach',data=data)

# %%
#exang与target关系
sns.countplot(x='exang',hue='target',data=data)

# %%
#oldpeak与target关系
sns.boxplot(x='target',y='oldpeak',data=data)

# %%
#slope与target
sns.countplot(x='slope',hue='target',data=data)

# %%
#ca与target
sns.countplot(x='ca',hue='target',data=data)

# %%
#thal与target
sns.countplot(x='thal',hue='target',data=data)

# %%
#target
sns.countplot(x='target',data=data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x_train,x_test,y_train,y_test = train_test_split(data.iloc[:,:-1],data.iloc[:,-1])
lgr =LogisticRegression()
lgr.fit(x_train,y_train)
print(lgr.score(x_test,y_test))
# Out:
# 0.868421052631579

# %%
#随机森林
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
print(rfc.score(x_test,y_test))
# Out:
# 0.9078947368421053

# %%
# Out:
# 0.8552631578947368
